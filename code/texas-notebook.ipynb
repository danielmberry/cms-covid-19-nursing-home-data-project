# %% [markdown]
# # Texas: ARIMA Time-Series Modeling Notebook

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from collections import Counter

from sklearn.model_selection import train_test_split

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read in data

# %%
# df = pd.read_csv('../COVID-19_Nursing_Home_Dataset.csv')

# %% [markdown]
# ## Split data

# %% [markdown]
# Due to size of data file, split data by week submitted to get smaller files that are available to upload.
# > This is commented out so that it only runs when needed.

# %%
# def split_data(df,dates):
#     for date in dates:    
#         frame = df[df['Week Ending'] == date]
#         reformatted_date = date.replace('/', '-')
#         frame.to_csv(f'../data/{reformatted_date}-data.csv', index = False)

# dates = df['Week Ending'].unique()

# split_data(df, dates)

# %% [markdown]
# ## Concatenating files

# %% [markdown]
# Create a function that can concatenate the each of the csv files into a single data frame.

# %%
df_lst = []
for f in os.listdir('../data'):
    temp = pd.read_csv('../data/' + f)
    df_lst.append(temp)
df = pd.concat(df_lst, ignore_index=True)

# %%
# determining the number of weeks for which data is available
week_num = len(df['Week Ending'].unique())
print('num weeks:',week_num)

# Dropping rows where no submitted data
df = df[df['Submitted Data'] == 'Y']

# dropping rows that didn't pass quality assurance check
df = df[df['Passed Quality Assurance Check'] == 'Y']
# Out:
# num weeks: 38

# %%
# removing nursing homes who have submissions for each week

submission_counts = Counter(df['Federal Provider Number'])
keys = submission_counts.keys()
to_drop = []
for key in keys:
    if submission_counts[key] < week_num:
        to_drop.append(key)
to_keep = keys-to_drop
print('original:',len(keys))
print('to be dropped:',len(to_drop))
print('to keep:',len(to_keep))
# Out:
# original: 16896
# to be dropped: 5914
# to keep: 10982

# %%
# drop rows for nursing homes that don't meet the criteria fewer entries
df = df[df['Federal Provider Number'].isin(to_keep)]

# %%
# change the week column to datetime format
df['Week Ending'] = pd.to_datetime(df['Week Ending'])

# %% [markdown]
# # Modeling

# %%
# function to get the p-values for adfuller test for each of the columns in the dataframe 

def interpret_dftest(df):
    '''
    Returns p-value for the Dickey-Fuller test for each feature in DataFrame.
    ----
    Parameters
        Type: DataFrame
        Description: Time series features
    ----
    Output
        Type: DataFrame
        Description: DataFrame of p-values for time-series data
    '''
    results = []
    best_col = None
    best_p = 2
    
    for col in df.columns:
        result = {}
        result['column'] = col
        dftest = adfuller(df[col])
        result['Test Statistic'] = dftest[0]
        result['p-value'] = dftest[1]
        result['1 - p-value'] = 1-dftest[1]
        results.append(result)
        if dftest[1] < .9:
            if dftest[1] < best_p:
                best_p = dftest[1]
                best_col = col
        elif dftest[1] >= .9:
            if (1-dftest[1]) < best_p:
                best_p = (1-dftest[1])
                best_col = col
    
    print('best_col:', best_col)
    print('best_p:', best_p)
    return pd.DataFrame(results)

# %% [markdown]
# ## TX

# %%
tx = df[df['Provider State']=='TX']

tx = tx[[
    'Week Ending', 'Total Number of Occupied Beds',
    'Residents Weekly COVID-19 Deaths',
    'Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents',
    'Weekly Resident COVID-19 Deaths Per 1,000 Residents'
]]
tx_avgs = tx.groupby(by='Week Ending').mean()

# %% [markdown]
# ### 'Total Number of Occupied Beds'

# %%
tx_occupied = tx_avgs[['Total Number of Occupied Beds']].copy()
tx_occupied['diff1'] = tx_occupied['Total Number of Occupied Beds'].diff()
tx_occupied['diff2'] = tx_occupied['Total Number of Occupied Beds'].diff().diff()
tx_occupied.dropna(inplace = True)

# %%
tx_occupied['Total Number of Occupied Beds'].plot(label = 'orig');

# %%
plot_acf(tx_occupied['Total Number of Occupied Beds']);

# %%
plot_pacf(tx_occupied['Total Number of Occupied Beds']);

# %%
interpret_dftest(tx_occupied)
# Out:
# best_col: diff1
# best_p: 1.637152579667575e-17
#                           column  Test Statistic       p-value  1 - p-value
# 0  Total Number of Occupied Beds       -0.851025  8.036728e-01     0.196327
# 1                          diff1      -10.025398  1.637153e-17     1.000000
# 2                          diff2       -5.026459  1.966712e-05     0.999980

# %%
y_train, y_test = train_test_split(tx_occupied['Total Number of Occupied Beds'],shuffle=False, test_size = .1)

# %% [markdown]
# *Note: The code in the two cells directly below, as well as all other iterations of it in this notebook, were adapted from the [7.07-lesson-arima-modeling repo](https://git.generalassemb.ly/DSIR-20201214-E/lesson-ARIMA), originally written by Matt Brems, Joseph Nelson and Justin Pounders.*

# %%
# Starting AIC, p, and q.
best_aic = 9 * (10**16)
best_p = 0
best_q = 0 
best_d = 0

# Use nested for loop to iterate over values of p and q.

for p in range(5):
    for q in range(5):
        for d in range(3):
        
        # Insert try and except statements.
            try:
                # Instantiate ARIMA model.
                arima = ARIMA(endog=y_train, order = (p, d, q))

                # Fit ARIMA model.
                model = arima.fit()

                # Is my current model's AIC better than our best_aic?
                if 0<= model.aic < best_aic:

                    # If so, let's overwrite best_aic, best_p, and best_q.
                    best_aic = model.aic
                    best_p = p
                    best_q = q
                    best_d = d
                    
            except:
                pass
            
print('best aic:',best_aic)
print('best p:', best_p)
print('best d:', best_d)
print('best q:', best_q)
# Out:
# best aic: 73.07216811919567
# best p: 1
# best d: 2
# best q: 1

# %%
# Instantiate best model.
tx_occ_model = ARIMA(endog=y_train, order=(best_p, best_d, best_q))

# Fit ARIMA model.
arima = tx_occ_model.fit()

# Generate predictions based on test set.
preds = arima.predict(start=y_test.index[0], end=y_test.index[-1])

# Plot data.
plt.figure(figsize=(10, 6))

# Plot training data.
plt.plot(y_train.index, pd.DataFrame(y_train), color='blue', label='Train')

# Plot testing data.
plt.plot(y_test.index, pd.DataFrame(y_test), color='orange', label='Test')

# Plot predicted test values.
plt.plot(y_test.index, preds, color='green', label='Preds')

plt.title(
    label=f'Texas Average Number of Occupied Beds\n with ARIMA({best_p}, {best_d}, {best_q}) Predictions',
    fontsize=16)
plt.legend()

plt.savefig('../assets/tx_avg_num_occupied_beds.png');

# %% [markdown]
# ### 'Residents Weekly COVID-19 Deaths'

# %%
tx_weekly_deaths = tx_avgs[['Residents Weekly COVID-19 Deaths']].copy()

tx_weekly_deaths['diff1'] = tx_weekly_deaths['Residents Weekly COVID-19 Deaths'].diff()
tx_weekly_deaths['diff2'] = tx_weekly_deaths['Residents Weekly COVID-19 Deaths'].diff().diff()
tx_weekly_deaths.dropna(inplace = True)

# %%
tx_weekly_deaths['Residents Weekly COVID-19 Deaths'].plot(label = 'orig');

# %%
plot_acf(tx_weekly_deaths['Residents Weekly COVID-19 Deaths']);

# %%
plot_pacf(tx_weekly_deaths['Residents Weekly COVID-19 Deaths']);

# %%
interpret_dftest(tx_weekly_deaths)
# Out:
# best_col: Residents Weekly COVID-19 Deaths
# best_p: 0.061254559752303414
#                              column  Test Statistic   p-value  1 - p-value
# 0  Residents Weekly COVID-19 Deaths       -2.779552  0.061255     0.938745
# 1                             diff1       -2.647611  0.083551     0.916449
# 2                             diff2       -2.446652  0.129000     0.871000

# %%
y_train, y_test = train_test_split(tx_weekly_deaths['Residents Weekly COVID-19 Deaths'],shuffle=False, test_size = .1)

# %%
# Starting AIC, p, and q.
best_aic = 9 * (10**16)
best_p = 0
best_q = 0 
best_d = 0
# Use nested for loop to iterate over values of p and q.

for p in range(5):
    for q in range(5):
        for d in range(3):
        
        # Insert try and except statements.
            try:

                # Instantiate ARIMA model.
                arima = ARIMA(endog=y_train, order = (p, d, q))

                # Fit ARIMA model.
                model = arima.fit()

                # Is my current model's AIC better than our best_aic?
                if 0 <= model.aic < best_aic:

                    # If so, let's overwrite best_aic, best_p, and best_q.
                    best_aic = model.aic
                    best_p = p
                    best_q = q
                    best_d = d
                    

            except:
                pass
            
print('best aic:',best_aic)
print('best p:', best_p)
print('best d:', best_d)
print('best q:', best_q)
# Out:
# best aic: 90000000000000000
# best p: 0
# best d: 0
# best q: 0

# %%
# Instantiate best model.
tx_week_deaths_model = ARIMA(endog = y_train, order = (best_p,best_d,best_q))

# Fit ARIMA model.
arima = tx_week_deaths_model.fit()

# Generate predictions based on test set.
preds = arima.predict(start = y_test.index[0], end= y_test.index[-1])

# Plot data.
plt.figure(figsize=(10,6))

# Plot training data.
plt.plot(y_train.index, pd.DataFrame(y_train), color = 'blue', label='Train')

# Plot testing data.
plt.plot(y_test.index, pd.DataFrame(y_test), color = 'orange', label = 'Test')

# Plot predicted test values.
plt.plot(y_test.index, preds, color = 'green', label = 'Preds')

plt.title(label = f'Texas Average Weekly COVID-19 Deaths\n with ARIMA({best_p}, {best_d}, {best_q}) Predictions', fontsize=16)
plt.legend()

plt.savefig('../assets/tx_weekly_avg_num_covid_deaths.png');

# %% [markdown]
# ### 'Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents'

# %%
tx_weekly_confirmed_cases = tx_avgs[['Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents']].copy()

tx_weekly_confirmed_cases['diff1'] = tx_weekly_confirmed_cases['Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents'].diff()
tx_weekly_confirmed_cases['diff2'] = tx_weekly_confirmed_cases['Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents'].diff().diff()
tx_weekly_confirmed_cases.dropna(inplace = True)

# %%
tx_weekly_confirmed_cases['Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents'].plot(label = 'orig');

# %%
plot_acf(tx_weekly_confirmed_cases['Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents']);

# %%
plot_pacf(tx_weekly_confirmed_cases['Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents']);

# %%
interpret_dftest(tx_weekly_confirmed_cases)
# Out:
# best_col: diff2
# best_p: 4.826077315069756e-07
#                                               column  Test Statistic  \
# 0  Weekly Resident Confirmed COVID-19 Cases Per 1...       -2.084768
# 1                                              diff1       -3.276347
# 2                                              diff2       -5.792893
#
#         p-value  1 - p-value
# 0  2.506834e-01     0.749317
# 1  1.596942e-02     0.984031
# 2  4.826077e-07     1.000000

# %%
y_train, y_test = train_test_split(tx_weekly_confirmed_cases['Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents'],shuffle=False, test_size = .1)

# %%
# Starting AIC, p, and q.
best_aic = 9 * (10**16)
best_p = 0
best_q = 0 
best_d = 0
# Use nested for loop to iterate over values of p and q.

for p in range(5):
    for q in range(5):
        for d in range(3):
        
        # Insert try and except statements.
            try:

                # Instantiate ARIMA model.
                arima = ARIMA(endog=y_train, order = (p, d, q))

                # Fit ARIMA model.
                model = arima.fit()

                # Is my current model's AIC better than our best_aic?
                if 0<= model.aic < best_aic:

                    # If so, let's overwrite best_aic, best_p, and best_q.
                    best_aic = model.aic
                    best_p = p
                    best_q = q
                    best_d = d
                    

            except:
                pass

print('best aic:',best_aic)
print('best p:', best_p)
print('best d:', best_d)
print('best q:', best_q)
# Out:
# best aic: 168.2099398132062
# best p: 1
# best d: 2
# best q: 1

# %%
# Instantiate best model.
tx_week_conf_cases_per_thous_model = ARIMA(endog = y_train, order = (best_p,best_d,best_q))

# Fit ARIMA model.
arima = tx_week_conf_cases_per_thous_model.fit()

# Generate predictions based on test set.
preds = arima.predict(start = y_test.index[0], end= y_test.index[-1])

# Plot data.
plt.figure(figsize=(10,6))

# Plot training data.
plt.plot(y_train.index, pd.DataFrame(y_train), color = 'blue', label='Train')

# Plot testing data.
plt.plot(y_test.index, pd.DataFrame(y_test), color = 'orange', label = 'Test')

# Plot predicted test values.
plt.plot(y_test.index, preds, color = 'green', label = 'Preds')

plt.title(label = f'Texas Weekly Average Number of Confirmed Cases per 1,000\n with ARIMA({best_p}, {best_d}, {best_q}) Predictions', fontsize=16)
plt.legend()

plt.savefig('../assets/tx_avg_num_confirmed_cases_per_thous.png');

# %% [markdown]
# ### 'Weekly Resident COVID-19 Deaths Per 1,000 Residents'

# %%
tx_weekly_covid_deaths_per_thous = tx_avgs[['Weekly Resident COVID-19 Deaths Per 1,000 Residents']].copy()

tx_weekly_covid_deaths_per_thous['diff1'] = tx_weekly_covid_deaths_per_thous['Weekly Resident COVID-19 Deaths Per 1,000 Residents'].diff()
tx_weekly_covid_deaths_per_thous['diff2'] = tx_weekly_covid_deaths_per_thous['Weekly Resident COVID-19 Deaths Per 1,000 Residents'].diff().diff()
tx_weekly_covid_deaths_per_thous.dropna(inplace = True)

# %%
tx_weekly_covid_deaths_per_thous['Weekly Resident COVID-19 Deaths Per 1,000 Residents'].plot(label = 'orig');

# %%
plot_acf(tx_weekly_covid_deaths_per_thous['Weekly Resident COVID-19 Deaths Per 1,000 Residents']);

# %%
plot_pacf(tx_weekly_covid_deaths_per_thous['Weekly Resident COVID-19 Deaths Per 1,000 Residents']);

# %%
interpret_dftest(tx_weekly_covid_deaths_per_thous)
# Out:
# best_col: diff2
# best_p: 1.6137134708595227e-06
#                                               column  Test Statistic  \
# 0  Weekly Resident COVID-19 Deaths Per 1,000 Resi...       -2.406721
# 1                                              diff1       -3.651941
# 2                                              diff2       -5.551781
#
#     p-value  1 - p-value
# 0  0.139848     0.860152
# 1  0.004842     0.995158
# 2  0.000002     0.999998

# %%
y_train, y_test = train_test_split(tx_weekly_covid_deaths_per_thous['Weekly Resident COVID-19 Deaths Per 1,000 Residents'],shuffle=False, test_size = .1)

# %%
# Starting AIC, p, and q.
best_aic = 9 * (10**16)
best_p = 0
best_q = 0 
best_d = 0
# Use nested for loop to iterate over values of p and q.

for p in range(5):
    for q in range(5):
        for d in range(3):
        
        # Insert try and except statements.
            try:

                # Instantiate ARIMA model.
                arima = ARIMA(endog=y_train, order = (p, d, q))

                # Fit ARIMA model.
                model = arima.fit()

                # Is my current model's AIC better than our best_aic?
                if 0<= model.aic < best_aic:

                    # If so, let's overwrite best_aic, best_p, and best_q.
                    best_aic = model.aic
                    best_p = p
                    best_q = q
                    best_d = d
                    

            except:
                pass
            
print('best aic:',best_aic)
print('best p:', best_p)
print('best d:', best_d)
print('best q:', best_q)
# Out:
# best aic: 71.46537686866317
# best p: 1
# best d: 1
# best q: 0

# %%
# Instantiate best model.
tx_weekly_deaths_per_thous_model = ARIMA(endog = y_train, order = (best_p,best_d,best_q))

# Fit ARIMA model.
arima = tx_weekly_deaths_per_thous_model.fit()

# Generate predictions based on test set.
preds = arima.predict(start = y_test.index[0], end= y_test.index[-1])

# Plot data.
plt.figure(figsize=(10,6))

# Plot training data.
plt.plot(y_train.index, pd.DataFrame(y_train), color = 'blue', label='Train')

# Plot testing data.
plt.plot(y_test.index, pd.DataFrame(y_test), color = 'orange', label = 'Test')

# Plot predicted test values.
plt.plot(y_test.index, preds, color = 'green', label = 'Preds')

plt.title(label = f'Texas Average of Weekly COVID-19 Deaths per 1,000\n with ARIMA({best_p}, {best_d}, {best_q}) Predictions', fontsize=16)
plt.legend()

plt.savefig('../assets/tx_weekly_avg_covid_deaths_per_1000.png');
